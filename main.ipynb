# %%
# !wget -q https://raw.githubusercontent.com/tsunrise/colab-github/main/colab_github.py
import colab_github
colab_github.github_auth(persistent_key=True)
# Out:
# Mounted at /content/drive/
# Looks that a private key is already created. If you have already push it to github, no action required.
#  Otherwise, Please go to https://github.com/settings/ssh/new to upload the following key:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIChzy91Hi8TkSPvjjkB3812lXfZDZAZH9/Hdg7lIJgOB root@272a5b5ab8d3
#
# Please use SSH method to clone repo.

# %%
# !git clone git@github.com:oliverdantzer/elec475-lab3.git
# Out:
# Cloning into 'elec475-lab2'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 78 (delta 25), reused 73 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 24.00 KiB | 511.00 KiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
import sys
sys.path.insert(0,'/content/elec475-lab3')

# %%
import os
os.system("pip install -r requirements.txt")

# %%
import src.download_dataset as dl_dataset
dl_dataset.main()
